# %% [markdown]
# ## Assignment 3
#     1. Name: Digambar Chaure
#     2. Batch: P-10
#     3. Roll No.: 43216
#
#    ### Problem Statement :
#     Build the Image classification model

# %% [markdown]
# #### Importing the libraries

# %%
import matplotlib.pyplot as plt
import tensorflow as tf
from tensorflow.keras import datasets, layers, models

# %% [markdown]
# #### a. Loading and preprocessing the image data
# #### Grabbing CIFAR10 dataset

# %%
(train_images, train_labels), (test_images, test_labels) = datasets.cifar10.load_data()
train_images, test_images = train_images / 255.0, test_images / 255.0
# Out:
# Downloading data from https://www.cs.toronto.edu/~kriz/cifar-10-python.tar.gz
# 170498071/170498071 [==============================] - 137s 1us/step

# %%
type(train_images)
# Out:
# numpy.ndarray

# %% [markdown]
# ####  Showing images of mentioned categories

# %%
class_names = ['airplane', 'automobile', 'bird', 'cat', 'deer','dog', 'frog', 'horse', 'ship', 'truck']

plt.figure(figsize=(10,10))
for i in range(10):
    plt.subplot(5,5,i+1)
    plt.xticks([])
    plt.yticks([])
    plt.grid(False)
    plt.imshow(train_images[i])
    plt.xlabel(class_names[train_labels[i][0]])
plt.show()

# %% [markdown]
# #### b. Defining the model’s architecture
# #### Building CNN model

# %%
model = models.Sequential()
model.add(layers.Conv2D(32, (3, 3), activation='relu', input_shape=(32, 32, 3)))
model.add(layers.MaxPooling2D((2, 2)))
model.add(layers.Conv2D(64, (3, 3), activation='relu'))
model.add(layers.MaxPooling2D((2, 2)))
model.add(layers.Conv2D(64, (3, 3), activation='relu'))
model.add(layers.Flatten())
model.add(layers.Dense(64, activation='relu'))
model.add(layers.Dense(10))

model.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  conv2d (Conv2D)             (None, 30, 30, 32)        896
#
#  max_pooling2d (MaxPooling2  (None, 15, 15, 32)        0
#  D)
#
#  conv2d_1 (Conv2D)           (None, 13, 13, 64)        18496
#
#  max_pooling2d_1 (MaxPoolin  (None, 6, 6, 64)          0
#  g2D)
#
#  conv2d_2 (Conv2D)           (None, 4, 4, 64)          36928
#
#  flatten (Flatten)           (None, 1024)              0
#
#  dense (Dense)               (None, 64)                65600
#
#  dense_1 (Dense)             (None, 10)                650
#
# =================================================================
# Total params: 122570 (478.79 KB)
# Trainable params: 122570 (478.79 KB)
# Non-trainable params: 0 (0.00 Byte)
# _________________________________________________________________

# %% [markdown]
# #### c. Training the model
# #### Model compilation

# %%
model.compile(optimizer='adam',loss=tf.keras.losses.SparseCategoricalCrossentropy(from_logits=True),metrics=['accuracy'])

# %% [markdown]
# #### d. Estimating the model’s performance

# %%
epochs = 10
h = model.fit(train_images, train_labels, epochs=epochs, validation_data=(test_images, test_labels))
# Out:
# Epoch 1/10
# 1563/1563 [==============================] - 53s 33ms/step - loss: 1.5080 - accuracy: 0.4529 - val_loss: 1.2156 - val_accuracy: 0.5655
# Epoch 2/10
# 1563/1563 [==============================] - 66s 42ms/step - loss: 1.1301 - accuracy: 0.6011 - val_loss: 1.0545 - val_accuracy: 0.6240
# Epoch 3/10
# 1563/1563 [==============================] - 70s 45ms/step - loss: 0.9707 - accuracy: 0.6599 - val_loss: 0.9622 - val_accuracy: 0.6608
# Epoch 4/10
# 1563/1563 [==============================] - 69s 44ms/step - loss: 0.8745 - accuracy: 0.6936 - val_loss: 0.9276 - val_accuracy: 0.6733
# Epoch 5/10
# 1563/1563 [==============================] - 57s 37ms/step - loss: 0.7940 - accuracy: 0.7232 - val_loss: 0.9097 - val_accuracy: 0.6830
# Epoch 6/10
# 1563/1563 [==============================] - 62s 40ms/step - loss: 0.7349 - accuracy: 0.7430 - val_loss: 0.8923 - val_accuracy: 0.6933
# Epoch 7/10
# 1563/1563 [==============================] - 53s 34ms/step - loss: 0.6854 - accuracy: 0.7590 - val_loss: 0.9072 - val_accuracy: 0.6892
# Epoch 8/10
# 1563/1563 [==============================] - 63s 40ms/step - loss: 0.6391 - accuracy: 0.7753 - val_loss: 0.8527 - val_accuracy: 0.7140
# Epoch 9/10
# 1563/1563 [==============================] - 52s 33ms/step - loss: 0.5983 - accuracy: 0.7899 - val_loss: 0.8858 - val_accuracy: 0.7103
# Epoch 10/10
# 1563/1563 [==============================] - 76s 48ms/step - loss: 0.5551 - accuracy: 0.8027 - val_loss: 0.9147 - val_accuracy: 0.7060
